# %% [markdown]
# # Carga Datos Almendro
# ## Pablo Lavín
# ## TFM - Master Ciencia de Datos (UC-UIMP)
# ## Beca JAE Intro ICU 2025
# ## Septiembre 2025 - Junio 2026

# %% [markdown]
# En este notebook se realiza la carga y preprocesamiento de los datos climáticos para el periodo 1982-2016 y 2018–2022, empleando proyecciones del modelo del Centro Europeo (ECMWF) y observaciones de referencia del reanálisis ERA5-Land.
#
# El análisis se centra en las temperaturas máximas y mínimas de las estaciones de enero y febrero (fases críticas de la floración del almendro), preparando la información para su posterior evaluación y comparación.

# %% [markdown]
# ## Configuración

# %%
# Cargamos paquetes
source("../../scripts/setup_libraries.R")
source("../../scripts/load_bc_functions.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: rJava
#
# Loading required package: loadeR.java
#
# Java version 23x amd64 by N/A detected
#
# NetCDF Java Library v4.6.0-SNAPSHOT (23 Apr 2015) loaded and ready
#
# Loading required package: climate4R.UDG
#
# climate4R.UDG version 0.2.6 (2023-06-26) is loaded
#
# Please use 'citation("climate4R.UDG")' to cite this package.
#
# loadeR version 1.8.1 (2023-06-22) is loaded
#
# WARNING: Your current version of loadeR (v1.8.1) is not up-to-date
#
# Get the latest stable version (1.8.2) using <devtools::install_github(c('SantanderMetGroup/climate4R.UDG','SantanderMetGroup/loadeR'))>
#
# Please use 'citation("loadeR")' to cite this package.
#     _______   ____  ___________________  __  ________
#    / ___/ /  / /  |/  / __  /_  __/ __/ / / / / __  /
#   / /  / /  / / /|_/ / /_/ / / / / __/ / /_/ / /_/_/
#  / /__/ /__/ / /  / / __  / / / / /__ /___  / / \ \
#  \___/____/_/_/  /_/_/ /_/ /_/  \___/    /_/\/   \_\
#
#       github.com/SantanderMetGroup/climate4R
# transformeR version 2.2.2 (2023-10-26) is loaded
#
# WARNING: Your current version of transformeR (v2.2.2) is not up-to-date
#
# Get the latest stable version (2.2.3) using <devtools::install_github('SantanderMetGroup/transformeR')>
#
# Please see 'citation("transformeR")' to cite this package.
#
# Loading required package: udunits2
#
# udunits system database read from /vols/abedul/home/meteo/lavinp/miniforge3/envs/C4R/share/udunits/udunits2.xml
#
# convertR version 0.3.0 (2025-07-31) is loaded
#
# WARNING: Your current version of convertR (v0.3.0) is ahead of the master branch version (0.2.1)
#
# Development version may have an unexpected behaviour
#
#   More information about the 'climate4R' ecosystem in: http://meteo.unican.es/climate4R
#
#
# Attaching package: ‘convertR’
#
#
# The following objects are masked from ‘package:loadeR’:
#
#     hurs2huss, huss2hurs, tdps2hurs
#
#
# visualizeR version 1.6.4 (2023-10-26) is loaded
#
# Please see 'citation("visualizeR")' to cite this package.
#
# downscaleR version 3.3.4 (2023-06-22) is loaded
#
# Please use 'citation("downscaleR")' to cite this package.
#
# Loading required package: climdex.pcic
#
# Loading required package: PCICt
#
# climate4R.climdex version 0.2.3 (2023-06-23) is loaded
#
# Use 'climdexShow()' for an overview of the available ETCCDI indices
#
# climate4R.indices version 0.3.1 (2023-06-22) is loaded
#
# Use 'indexShow()' for an overview of the available climate indices and circIndexShow() for the circulation indices.
#
# NOTE: use package climate4R.climdex to calculate ETCCDI indices.
#
#
# Attaching package: ‘climate4R.indices’
#
#
# The following object is masked from ‘package:transformeR’:
#
#     lambWT
#
#
# Loading required package: SpecsVerification
#
#
# Attaching package: ‘easyVerification’
#
#
# The following object is masked from ‘package:SpecsVerification’:
#
#     EnsCorr
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
# Region de estudio

lon = c(-10, 5)
lat = c(35, 44)

# %% [markdown]
# ## Cargar hindcast tasmax (leadtime 0, 1, 2, 3)

# %%
anios = 1982:2016
meses_ini = c("01", "12", "11", "10")  # meses de inicialización

# Función generalizada para cargar los datos por mes y año
cargar_dato = function(anio, mes_ini) {

    # Ajustar año si el mes de inicialización es del año anterior
    if (mes_ini %in% c("10", "11", "12")) {
        anio = anio - 1
    }

    yyyymm = paste0(anio, mes_ini)

    ruta = paste0(
        "/lustre/gmeteo/PTICLIMA/DATA/SEASONAL/",
        "seasonal-original-single-levels/medcof/hindcast/tasmax/ecmwf/51/", yyyymm, "/",
        "seasonal-original-single-levels_medcof_hindcast_tasmax_ecmwf_51_", yyyymm, ".ncml"
    )

    data_aux = loadGridData(dataset = ruta,
                            var = "tasmax",
                            lonLim = lon,
                            latLim = lat,
                            season = c(1, 2)) %>% suppressMessages %>% suppressWarnings

    return(data_aux)
}

# Creo una lista donde cada elemento es la salida para un mes de inicialización diferente
hindcast = lapply(meses_ini, function(mes) {
    lapply(anios, function(anio) cargar_dato(anio, mes))
})

# Nombro los elementos por mes
names(hindcast) = paste0("mes_", meses_ini)

# %%
# Asigno nombre a cada grid con los leadtime
tmx_ecmwf_0 = hindcast[["mes_04"]]
tmx_ecmwf_1 = hindcast[["mes_03"]]
tmx_ecmwf_2 = hindcast[["mes_02"]]
tmx_ecmwf_3 = hindcast[["mes_01"]]

# Combinamos los grids en la dimensión temporal
tmx_ecmwf_0_grid = bindGrid(tmx_ecmwf_0, dimension = "time")
tmx_ecmwf_1_grid = bindGrid(tmx_ecmwf_1, dimension = "time")
tmx_ecmwf_2_grid = bindGrid(tmx_ecmwf_2, dimension = "time")
tmx_ecmwf_3_grid = bindGrid(tmx_ecmwf_3, dimension = "time")

# %% [markdown]
# ## Cargar forecast tasmax (leadtime 0, 1, 2, 3)

# %%
anios = 2018:2022
meses_ini = c("01", "12", "11", "10")  # meses de inicialización

# Función generalizada para cargar los datos por mes y año
cargar_dato = function(anio, mes_ini) {

    # Ajustar año si el mes de inicialización es del año anterior
    if (mes_ini %in% c("10", "11", "12")) {
        anio = anio - 1
    }

    yyyymm = paste0(anio, mes_ini)

    ruta = paste0(
        "/lustre/gmeteo/PTICLIMA/DATA/SEASONAL/",
        "seasonal-original-single-levels/medcof/forecast/tasmax/ecmwf/51/", yyyymm, "/",
        "seasonal-original-single-levels_medcof_forecast_tasmax_ecmwf_51_", yyyymm, ".ncml"
    )

    data_aux = loadGridData(dataset = ruta,
                            var = "tasmax",
                            lonLim = lon,
                            latLim = lat,
                            season = c(1, 2)) %>% suppressMessages %>% suppressWarnings

    return(data_aux)
}

# Creo una lista donde cada elemento es la salida para un mes de inicialización diferente
forecast = lapply(meses_ini, function(mes) {
    lapply(anios, function(anio) cargar_dato(anio, mes))
})

# Nombro los elementos por mes
names(forecast) = paste0("mes_", meses_ini)

# %%
# Asigno nombre a cada grid con los leadtime
tmx_forecast_0 = forecast[["mes_01"]]
tmx_forecast_1 = forecast[["mes_12"]]
tmx_forecast_2 = forecast[["mes_11"]]
tmx_forecast_3 = forecast[["mes_10"]]

# Combinamos los grids en la dimensión temporal
tmx_forecast_0_grid = bindGrid(tmx_forecast_0, dimension = "time")
tmx_forecast_1_grid = bindGrid(tmx_forecast_1, dimension = "time")
tmx_forecast_2_grid = bindGrid(tmx_forecast_2, dimension = "time")
tmx_forecast_3_grid = bindGrid(tmx_forecast_3, dimension = "time")

# Selecciono los primeros 25 miembros
tmx_forecast_0_members = subsetGrid(tmx_forecast_0_grid, members = 1:25)
tmx_forecast_1_members = subsetGrid(tmx_forecast_1_grid, members = 1:25)
tmx_forecast_2_members = subsetGrid(tmx_forecast_2_grid, members = 1:25)
tmx_forecast_3_members = subsetGrid(tmx_forecast_3_grid, members = 1:25)

# Combinamos los grids de hindcast y forecast
tmx_ecmwf_0_grid = bindGrid(tmx_ecmwf_0_grid, tmx_forecast_0_members, dimension = "time")
tmx_ecmwf_1_grid = bindGrid(tmx_ecmwf_1_grid, tmx_forecast_1_members, dimension = "time")
tmx_ecmwf_2_grid = bindGrid(tmx_ecmwf_2_grid, tmx_forecast_2_members, dimension = "time")
tmx_ecmwf_3_grid = bindGrid(tmx_ecmwf_3_grid, tmx_forecast_3_members, dimension = "time")

# %% [markdown]
# ## Cargar tasmax ERA5-Land

# %%
# Define años y meses
anios = 1982:2022
anios = anios[anios != 2017]
meses = sprintf("%02d", c(1, 2))

# Función para construir la ruta y cargar los datos
cargar_dato = function(anio, mes) {
    yyyy = paste0(anio)
    yyyymm = paste0(anio, mes)
    ruta = paste0(
        "/lustre/gmeteo/PTICLIMA/DATA/REANALYSIS/ERA5-Land/data/Iberia/day/t2mx/", yyyy, "/",
        "t2mx_ERA5-Land_", yyyymm, ".nc"
    )
    
    # Carga el dataset
    data_aux = loadGridData(dataset = ruta,
                            var = "t2mx",
                            lonLim = lon,
                            latLim = lat) %>% suppressMessages %>% suppressWarnings

    return(data_aux)
}

# Crear combinaciones enero + febrero
combinaciones = do.call(rbind, lapply(anios, function(anio) {
  data.frame(
    anio = c(anio, anio),
    mes  = c("01", "02"),
    stringsAsFactors = FALSE
  )
}))

# Aplicar la función a cada combinación
tmx_era5 = lapply(1:nrow(combinaciones), function(i) {
    cargar_dato(combinaciones$anio[i], combinaciones$mes[i])
})

# Combinamos los grids en la dimensión temporal
tmx_era5_time = bindGrid(tmx_era5, dimension = "time")

# Upscaling de la resolución de las observaciones
tmx_era5_ups = interpGrid(tmx_era5_time,
                          new.coordinates = getGrid(tmx_ecmwf_0_grid),
                          method = "bilinear") %>% suppressMessages %>% suppressWarnings

# Pasamos las observaciones de Kelvin a Celsius
tmx_obs_cel = gridArithmetics(tmx_era5_ups, 273.15, operator = "-")

# %%
# Guardo los datos
saveRDS(tmx_ecmwf_0_grid, file = "tasmax_model_almen_0.rds")
saveRDS(tmx_ecmwf_1_grid, file = "tasmax_model_almen_1.rds")
saveRDS(tmx_ecmwf_2_grid, file = "tasmax_model_almen_2.rds")
saveRDS(tmx_ecmwf_3_grid, file = "tasmax_model_almen_3.rds")

saveRDS(tmx_obs_cel, file = "tasmax_obs_almen.rds")

# %% [markdown]
# ## Cargar hindcast tasmin (leadtime 0, 1, 2, 3)

# %%
anios = 1982:2016
meses_ini = c("01", "12", "11", "10")  # meses de inicialización

# Función generalizada para cargar los datos por mes y año
cargar_dato = function(anio, mes_ini) {

    # Ajustar año si el mes de inicialización es del año anterior
    if (mes_ini %in% c("10", "11", "12")) {
        anio = anio - 1
    }

    yyyymm = paste0(anio, mes_ini)

    ruta = paste0(
        "/lustre/gmeteo/PTICLIMA/DATA/SEASONAL/",
        "seasonal-original-single-levels/medcof/hindcast/tasmin/ecmwf/51/", yyyymm, "/",
        "seasonal-original-single-levels_medcof_hindcast_tasmin_ecmwf_51_", yyyymm, ".ncml"
    )

    data_aux = loadGridData(dataset = ruta,
                            var = "tasmin",
                            lonLim = lon,
                            latLim = lat,
                            season = c(1, 2)) %>% suppressMessages %>% suppressWarnings

    return(data_aux)
}

# Creo una lista donde cada elemento es la salida para un mes de inicialización diferente
hindcast = lapply(meses_ini, function(mes) {
    lapply(anios, function(anio) cargar_dato(anio, mes))
})

# Nombro los elementos por mes
names(hindcast) = paste0("mes_", meses_ini)

# %%
# Asigno nombre a cada grid con los leadtime
tmn_ecmwf_0 = hindcast[["mes_01"]]
tmn_ecmwf_1 = hindcast[["mes_12"]]
tmn_ecmwf_2 = hindcast[["mes_11"]]
tmn_ecmwf_3 = hindcast[["mes_10"]]

# Combinamos los grids en la dimensión temporal
tmn_ecmwf_0_grid = bindGrid(tmn_ecmwf_0, dimension = "time")
tmn_ecmwf_1_grid = bindGrid(tmn_ecmwf_1, dimension = "time")
tmn_ecmwf_2_grid = bindGrid(tmn_ecmwf_2, dimension = "time")
tmn_ecmwf_3_grid = bindGrid(tmn_ecmwf_3, dimension = "time")

# %% [markdown]
# ## Cargar forecast tasmin (leadtime 0, 1, 2, 3)

# %%
anios = 2018:2022
meses_ini = c("01", "12", "11", "10")  # meses de inicialización

# Función generalizada para cargar los datos por mes y año
cargar_dato = function(anio, mes_ini) {

    # Ajustar año si el mes de inicialización es del año anterior
    if (mes_ini %in% c("10", "11", "12")) {
        anio = anio - 1
    }

    yyyymm = paste0(anio, mes_ini)

    ruta = paste0(
        "/lustre/gmeteo/PTICLIMA/DATA/SEASONAL/",
        "seasonal-original-single-levels/medcof/forecast/tasmin/ecmwf/51/", yyyymm, "/",
        "seasonal-original-single-levels_medcof_forecast_tasmin_ecmwf_51_", yyyymm, ".ncml"
    )

    data_aux = loadGridData(dataset = ruta,
                            var = "tasmin",
                            lonLim = lon,
                            latLim = lat,
                            season = c(1, 2)) %>% suppressMessages %>% suppressWarnings

    return(data_aux)
}

# Creo una lista donde cada elemento es la salida para un mes de inicialización diferente
forecast = lapply(meses_ini, function(mes) {
    lapply(anios, function(anio) cargar_dato(anio, mes))
})

# Nombro los elementos por mes
names(forecast) = paste0("mes_", meses_ini)

# %%
# Asigno nombre a cada grid con los leadtime
tmn_forecast_0 = forecast[["mes_01"]]
tmn_forecast_1 = forecast[["mes_12"]]
tmn_forecast_2 = forecast[["mes_11"]]
tmn_forecast_3 = forecast[["mes_10"]]

# Combinamos los grids en la dimensión temporal
tmn_forecast_0_grid = bindGrid(tmn_forecast_0, dimension = "time")
tmn_forecast_1_grid = bindGrid(tmn_forecast_1, dimension = "time")
tmn_forecast_2_grid = bindGrid(tmn_forecast_2, dimension = "time")
tmn_forecast_3_grid = bindGrid(tmn_forecast_3, dimension = "time")

# Selecciono los primeros 25 miembros
tmn_forecast_0_members = subsetGrid(tmn_forecast_0_grid, members = 1:25)
tmn_forecast_1_members = subsetGrid(tmn_forecast_1_grid, members = 1:25)
tmn_forecast_2_members = subsetGrid(tmn_forecast_2_grid, members = 1:25)
tmn_forecast_3_members = subsetGrid(tmn_forecast_3_grid, members = 1:25)

# Combinamos los grids de hindcast y forecast
tmn_ecmwf_0_grid = bindGrid(tmn_ecmwf_0_grid, tmn_forecast_0_members, dimension = "time")
tmn_ecmwf_1_grid = bindGrid(tmn_ecmwf_1_grid, tmn_forecast_1_members, dimension = "time")
tmn_ecmwf_2_grid = bindGrid(tmn_ecmwf_2_grid, tmn_forecast_2_members, dimension = "time")
tmn_ecmwf_3_grid = bindGrid(tmn_ecmwf_3_grid, tmn_forecast_3_members, dimension = "time")

# %% [markdown]
# ## Cargar tasmin ERA5-Land

# %%
# Define años y meses
anios = 1982:2022
anios = anios[anios != 2017]
meses = sprintf("%02d", c(1, 2))

# Función para construir la ruta y cargar los datos
cargar_dato = function(anio, mes) {
    yyyy = paste0(anio)
    yyyymm = paste0(anio, mes)
    ruta = paste0(
        "/lustre/gmeteo/PTICLIMA/DATA/REANALYSIS/ERA5-Land/data/Iberia/day/t2mn/", yyyy, "/",
        "t2mn_ERA5-Land_", yyyymm, ".nc"
    )
    
    # Carga el dataset
    data_aux = loadGridData(dataset = ruta,
                            var = "t2mn",
                            lonLim = lon,
                            latLim = lat) %>% suppressMessages %>% suppressWarnings

    return(data_aux)
}

# Crear combinaciones enero + febrero
combinaciones = do.call(rbind, lapply(anios, function(anio) {
  data.frame(
    anio = c(anio, anio),
    mes  = c("01", "02"),
    stringsAsFactors = FALSE
  )
}))

# Aplicar la función a cada combinación
tmn_era5 = lapply(1:nrow(combinaciones), function(i) {
    cargar_dato(combinaciones$anio[i], combinaciones$mes[i])
})

# Combinamos los grids en la dimensión temporal
tmn_era5_time = bindGrid(tmn_era5, dimension = "time")

# Upscaling de la resolución de las observaciones
tmn_era5_ups = interpGrid(tmn_era5_time,
                          new.coordinates = getGrid(tmn_ecmwf_0_grid),
                          method = "bilinear") %>% suppressMessages %>% suppressWarnings

# Pasamos las observaciones de Kelvin a Celsius
tmn_obs_cel = gridArithmetics(tmn_era5_ups, 273.15, operator = "-")

# %%
# Guardo los datos
saveRDS(tmn_ecmwf_0_grid, file = "tasmin_model_almen_0.rds")
saveRDS(tmn_ecmwf_1_grid, file = "tasmin_model_almen_1.rds")
saveRDS(tmn_ecmwf_2_grid, file = "tasmin_model_almen_2.rds")
saveRDS(tmn_ecmwf_3_grid, file = "tasmin_model_almen_3.rds")

saveRDS(tmn_obs_cel, file = "tasmin_obs_almen.rds")
